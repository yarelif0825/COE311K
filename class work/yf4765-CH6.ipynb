# %%
import numpy as np
import time

def jacobi(A, b, x0, tol=1e-6, max_iterations=10000):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k + 1
        x = x_new
    return x, max_iterations

def gauss_seidel(A, b, x0, tol=1e-6, max_iterations=10000):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k + 1
        x = x_new
    return x, max_iterations

def run_methods(A, b, tol=1e-6):
    x0 = np.zeros_like(b)
    
    # Jacobi
    start = time.time()
    x_jacobi, iter_jacobi = jacobi(A, b, x0, tol)
    time_jacobi = time.time() - start

    # Gauss-Seidel
    start = time.time()
    x_gs, iter_gs = gauss_seidel(A, b, x0, tol)
    time_gs = time.time() - start

    print("Jacobi solution:", x_jacobi)
    print("Jacobi iterations:", iter_jacobi)
    print("Jacobi time(s):", time_jacobi)
    print("-" * 60)
    print("Gauss-Seidel solution:", x_gs)
    print("Gauss-Seidel iterations:", iter_gs)
    print("Gauss-Seidel time(s):", time_gs)
    print("=" * 60)

# Challenge 6a
print("Challenge 6a")
A_6a = np.array([
    [10, -1, 2, 0],
    [-1, 11, -1, 3],
    [2, -1, 10, -1],
    [0, 3, -1, 8]
], dtype=float)
b_6a = np.array([14, 30, 26, 37], dtype=float)
run_methods(A_6a, b_6a, tol=1e-6)

# Challenge 6b
print("Challenge 6b")
A_6b = np.array([
    [1, 2, 3],
    [2, 3, 1],
    [3, 2, 1]
], dtype=float)
b_6b = np.array([14, 33, 22], dtype=float)
run_methods(A_6b, b_6b, tol=1e-6)
# Out:
# Challenge 6a
# Jacobi solution: [0.98782974 1.92427295 3.02298867 4.28127089]
# Jacobi iterations: 18
# Jacobi time(s): 0.0011627674102783203
# ------------------------------------------------------------
# Gauss-Seidel solution: [0.98782966 1.92427313 3.0229885  4.28127114]
# Gauss-Seidel iterations: 8
# Gauss-Seidel time(s): 0.0007519721984863281
# ============================================================
# Challenge 6b
# <ipython-input-6-941c4088ed66>:10: RuntimeWarning: overflow encountered in double_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-6-941c4088ed66>:24: RuntimeWarning: overflow encountered in double_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
# <ipython-input-6-941c4088ed66>:23: RuntimeWarning: invalid value encountered in double_scalars
#   s1 = sum(A[i][j] * x_new[j] for j in range(i))
# Jacobi solution: [-inf -inf -inf]
# Jacobi iterations: 10000
# Jacobi time(s): 0.2941410541534424
# ------------------------------------------------------------
# Gauss-Seidel solution: [nan nan nan]
# Gauss-Seidel iterations: 10000
# Gauss-Seidel time(s): 0.22201848030090332
# ============================================================
