# %%
number = 2025
remainders = []

while number > 0: 
    remainder = number % 2
    remainders.append(str(remainder))
    number //= 2
    
binary_string = ''.join(remainders[::-1])
print(binary_string)
# Out:
# 11111101001
